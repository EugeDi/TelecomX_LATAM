# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json'
df = pd.read_json(url)
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ## Conociendo el conjunto de datos

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %% [markdown]
# ### Diccionario de datos

# %% [markdown]
# *   customerID: número de identificación único de cada cliente
# *   Churn: si el cliente dejó o no la empresa
# *   gender: género (masculino y femenino)
# *   SeniorCitizen: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# *   Partner: si el cliente tiene o no una pareja
# *   Dependents: si el cliente tiene o no dependientes
# *   tenure: meses de contrato del cliente
# *   PhoneService: suscripción al servicio telefónico
# *   MultipleLines: suscripción a más de una línea telefónica
# *   InternetService: suscripción a un proveedor de internet
# *   OnlineSecurity: suscripción adicional de seguridad en línea
# *   OnlineBackup: suscripción adicional de respaldo en línea
# *   DeviceProtection: suscripción adicional de protección del dispositivo
# *   TechSupport: suscripción adicional de soporte técnico, menor tiempo de espera
# *   StreamingTV: suscripción de televisión por cable
# *   StreamingMovies: suscripción de streaming de películas
# *   Contract: tipo de contrato
# *   PaperlessBilling: si el cliente prefiere recibir la factura en línea
# *   PaymentMethod: forma de pago
# *   Charges.Monthly: total de todos los servicios del cliente por mes
# *   Charges.Total: total gastado por el cliente

# %% [markdown]
# ### Selección de Columns

# %% [markdown]
# *   Churn: si el cliente dejó o no la empresa
# *   SeniorCitizen: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# *   tenure: meses de contrato del cliente
# *   PhoneService: suscripción al servicio telefónico
# *   MultipleLines: suscripción a más de una línea telefónica
# *   InternetService: suscripción a un proveedor de internet
# *   OnlineSecurity: suscripción adicional de seguridad en línea
# *   OnlineBackup: suscripción adicional de respaldo en línea
# *   DeviceProtection: suscripción adicional de protección del dispositivo
# *   TechSupport: suscripción adicional de soporte técnico, menor tiempo de espera
# *   StreamingTV: suscripción de televisión por cable
# *   StreamingMovies: suscripción de streaming de películas
# *   Contract: tipo de contrato
# *   PaperlessBilling: si el cliente prefiere recibir la factura en línea
# *   PaymentMethod: forma de pago
# *   Charges.Monthly: total de todos los servicios del cliente por mes
# *   Charges.Total: total gastado por el cliente

# %% [markdown]
# ## Estandarización y transformación de datos

# %% [markdown]
# ### DataFrame Flat

# %%
# Columna Base:
df_main = df[['Churn']]

# Columnas del diccionario 'customer'
df_customer = df['customer'].apply(pd.Series)[['SeniorCitizen', 'tenure']]

# Columnas del diccionario 'phone'
df_phone = df['phone'].apply(pd.Series)[['PhoneService', 'MultipleLines']]

# Columnas del diccionario 'internet'
df_internet = df['internet'].apply(pd.Series)[[
    'InternetService', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'
]]

# Columnas del diccionario 'account'
df_account = df['account'].apply(pd.Series)[['Contract', 'PaperlessBilling', 'PaymentMethod']]

# Columnas del diccionario 'Charges' dentro del diccionario 'account'
df_charges = df['account'].apply(lambda x: x['Charges']).apply(pd.Series)[['Monthly', 'Total']]

# DataFrame global
df_flat = pd.concat([df_main, df_customer, df_phone, df_internet, df_account, df_charges], axis=1)
df_flat
# Out:
#      Churn  SeniorCitizen  tenure PhoneService     MultipleLines  \
# 0       No              0       9          Yes                No
# 1       No              0       9          Yes               Yes
# 2      Yes              0       4          Yes                No
# 3      Yes              1      13          Yes                No
# 4      Yes              1       3          Yes                No
# ...    ...            ...     ...          ...               ...
# 7262    No              0      13          Yes                No
# 7263   Yes              0      22          Yes               Yes
# 7264    No              0       2          Yes                No
# 7265    No              0      67          Yes                No
# 7266    No              0      63           No  No phone service
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# ...

# %% [markdown]
# ### Verificación inicial

# %%
for col in df_flat.columns:
    print(f"\n{col}")
    print("Valores únicos:", df_flat[col].unique())
    print("Valores nulos:", df_flat[col].isna().sum())
    print("Espacios vacíos:", (df_flat[col] == ' ').sum())
# Out:
# Churn
# Valores únicos: ['No' 'Yes' '']
# Valores nulos: 0
# Espacios vacíos: 0
#
# SeniorCitizen
# Valores únicos: [0 1]
# Valores nulos: 0
# Espacios vacíos: 0
#
# tenure
# Valores únicos: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# Valores nulos: 0
# Espacios vacíos: 0
#
# PhoneService
# Valores únicos: ['Yes' 'No']
# Valores nulos: 0
# Espacios vacíos: 0
#
# MultipleLines
# Valores únicos: ['No' 'Yes' 'No phone service']
# Valores nulos: 0
# Espacios vacíos: 0
#
# InternetService
# Valores únicos: ['DSL' 'Fiber optic' 'No']
# Valores nulos: 0
# Espacios vacíos: 0
#
# OnlineSecurity
# Valores únicos: ['No' 'Yes' 'No internet service']
# Valores nulos: 0
# Espacios vacíos: 0
#
# OnlineBackup
# Valores únicos: ['Yes' 'No' 'No internet service']
# Valores nulos: 0
# Espacios vacíos: 0
#
# ...

# %% [markdown]
# ### Conversión de tipos de datos

# %%
# Copia del df_flat para su modificación segura
df_clean = df_flat.copy()

# Convierte a binario
cols_bin = [
    'Churn', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling'
]
df_clean[cols_bin] = df_clean[cols_bin].replace({'Yes': 1, 'No': 0})
# Out:
# <ipython-input-7-01d844125b9a>:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_clean[cols_bin] = df_clean[cols_bin].replace({'Yes': 1, 'No': 0})

# %%
# Verificación de NaN y espacios vacíos
cols_verif = [
    'Churn', 'SeniorCitizen', 'tenure', 'PhoneService', 'MultipleLines',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Monthly', 'Total'
]
errores = {}

for col in cols_verif:
    prueba = pd.to_numeric(df_clean[col], errors='coerce')
    resultado = prueba.isna()
    if resultado.any():
        errores[col] = df_clean.loc[resultado, col].value_counts()

for col, vals in errores.items():
    print(vals)
# Out:
# Churn
#     224
# Name: count, dtype: int64
# MultipleLines
# No phone service    707
# Name: count, dtype: int64
# OnlineSecurity
# No internet service    1581
# Name: count, dtype: int64
# OnlineBackup
# No internet service    1581
# Name: count, dtype: int64
# DeviceProtection
# No internet service    1581
# Name: count, dtype: int64
# TechSupport
# No internet service    1581
# Name: count, dtype: int64
# StreamingTV
# No internet service    1581
# Name: count, dtype: int64
# StreamingMovies
# No internet service    1581
# Name: count, dtype: int64
# Total
#     11
# Name: count, dtype: int64

# %%
# Elimina las rows con registros vacíos en 'Churn' o 'Total'
df_clean = df_clean.astype({'Churn': str, 'Total': str})
df_clean.drop(df_clean[(df_clean['Churn'].str.strip() == '') | (df_clean['Total'].str.strip() == '')].index, inplace=True)

# Reemplaza STR por binario (0)
df_clean.replace({'No phone service': 0, 'No internet service': 0}, inplace=True)

# Convierte a float
df_clean = df_clean.astype({'Monthly': float, 'Total': float})
# Vuelve a convertir a int64, luego de borrar los registros vacíos
df_clean['Churn'] = df_clean['Churn'].astype('int64')
# Convierte a str con lower case
cols_str = ['InternetService', 'Contract', 'PaymentMethod']
for col in cols_str:
    df_clean[col] = df_clean[col].astype(str).str.lower()

datos = df_clean.copy()
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7266
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7032 non-null   int64
#  1   SeniorCitizen     7032 non-null   int64
#  2   tenure            7032 non-null   int64
#  3   PhoneService      7032 non-null   int64
#  4   MultipleLines     7032 non-null   int64
#  5   InternetService   7032 non-null   object
#  6   OnlineSecurity    7032 non-null   int64
#  7   OnlineBackup      7032 non-null   int64
#  8   DeviceProtection  7032 non-null   int64
#  9   TechSupport       7032 non-null   int64
#  10  StreamingTV       7032 non-null   int64
#  11  StreamingMovies   7032 non-null   int64
#  12  Contract          7032 non-null   object
#  13  PaperlessBilling  7032 non-null   int64
#  14  PaymentMethod     7032 non-null   object
#  15  Monthly           7032 non-null   float64
# ...

# %% [markdown]
# ### Verificación

# %%
for col in datos.columns:
    print(f"\n{col}")
    print("Valores únicos:", datos[col].unique())
    print("Valores nulos:", datos[col].isna().sum())
    print("Espacios vacíos:", (datos[col] == ' ').sum())
# Out:
# Churn
# Valores únicos: [0 1]
# Valores nulos: 0
# Espacios vacíos: 0
#
# SeniorCitizen
# Valores únicos: [0 1]
# Valores nulos: 0
# Espacios vacíos: 0
#
# tenure
# Valores únicos: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42]
# Valores nulos: 0
# Espacios vacíos: 0
#
# PhoneService
# Valores únicos: [1 0]
# Valores nulos: 0
# Espacios vacíos: 0
#
# MultipleLines
# Valores únicos: [0 1]
# Valores nulos: 0
# Espacios vacíos: 0
#
# InternetService
# Valores únicos: ['dsl' 'fiber optic' 'no']
# Valores nulos: 0
# Espacios vacíos: 0
#
# OnlineSecurity
# Valores únicos: [0 1]
# Valores nulos: 0
# Espacios vacíos: 0
#
# OnlineBackup
# Valores únicos: [1 0]
# Valores nulos: 0
# Espacios vacíos: 0
#
# DeviceProtection
# Valores únicos: [0 1]
# Valores nulos: 0
# Espacios vacíos: 0
#
# TechSupport
# ...

# %% [markdown]
# ### Columna Cuentas_Diarias

# %%
datos['Cuentas_Diarias'] = (datos['Monthly'] / 30).round(2)
datos.head()
# Out:
#    Churn  SeniorCitizen  tenure  PhoneService  MultipleLines InternetService  \
# 0      0              0       9             1              0             dsl
# 1      0              0       9             1              1             dsl
# 2      1              0       4             1              0     fiber optic
# 3      1              1      13             1              0     fiber optic
# 4      1              1       3             1              0     fiber optic
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 0               0             1                 0            1            1
# 1               0             0                 0            0            0
# 2               0             0                 1            0            0
# 3               0             1                 1            0            1
# 4               0             0                 0            1            1
#
# ...

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ### Análisis Descriptivo

# %%
datos.describe()
# Out:
#              Churn  SeniorCitizen       tenure  PhoneService  MultipleLines  \
# count  7032.000000    7032.000000  7032.000000   7032.000000    7032.000000
# mean      0.265785       0.162400    32.421786      0.903299       0.421928
# std       0.441782       0.368844    24.545260      0.295571       0.493902
# min       0.000000       0.000000     1.000000      0.000000       0.000000
# 25%       0.000000       0.000000     9.000000      1.000000       0.000000
# 50%       0.000000       0.000000    29.000000      1.000000       0.000000
# 75%       1.000000       0.000000    55.000000      1.000000       1.000000
# max       1.000000       1.000000    72.000000      1.000000       1.000000
#
#        OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# count     7032.000000   7032.000000       7032.000000  7032.000000
# mean         0.286547      0.344852          0.343857     0.290102
# std          0.452180      0.475354          0.475028     0.453842
# ...

# %%
# Estadísticas en variables binarias
cols_bin = [
    'Churn', 'SeniorCitizen', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling'
]
print("Media de:")
print(datos[cols_bin].mean().round(2).sort_values())

# Estadística en variables numéricas
cols_num = ['tenure', 'Monthly', 'Total', 'Cuentas_Diarias']
print("\nValores estadísticos de:")
print(datos[cols_num].describe().drop(index='count').round(2))

# Estadística en variables str
cols_str = ['InternetService', 'Contract', 'PaymentMethod']
print("\nDistribución de valores por variable str:")
for col in cols_str:
    print(f"\n{datos[col].value_counts(normalize=True).round(2)}")
# Out:
# Media de:
# SeniorCitizen       0.16
# Churn               0.27
# TechSupport         0.29
# OnlineSecurity      0.29
# OnlineBackup        0.34
# DeviceProtection    0.34
# StreamingTV         0.38
# StreamingMovies     0.39
# MultipleLines       0.42
# PaperlessBilling    0.59
# PhoneService        0.90
# dtype: float64
#
# Valores estadísticos de:
#       tenure  Monthly    Total  Cuentas_Diarias
# mean   32.42    64.80  2283.30             2.16
# std    24.55    30.09  2266.77             1.00
# min     1.00    18.25    18.80             0.61
# 25%     9.00    35.59   401.45             1.19
# 50%    29.00    70.35  1397.48             2.34
# 75%    55.00    89.86  3794.74             2.99
# max    72.00   118.75  8684.80             3.96
#
# Distribución de valores por variable str:
#
# InternetService
# fiber optic    0.44
# dsl            0.34
# no             0.22
# Name: proportion, dtype: float64
#
# Contract
# month-to-month    0.55
# two year          0.24
# ...

# %% [markdown]
# ### Gráfico de distribución de evasión / Porcentaje de clientes que se dieron de baja

# %%
import matplotlib.pyplot as plt

# Gráfico de Churn
churn_total = datos['Churn'].value_counts()
plt.figure(figsize=(4,4))
plt.pie(churn_total, labels=['Activos', 'Baja'], autopct='%1.2f%%', startangle=90, colors=['lightblue', 'crimson'])
plt.title('Proporción de clientes activos y dados de baja')
plt.show()

# %% [markdown]
# ### Gráfico de distribución de evasión de clientes por variables categóricas

# %%
import plotly.express as px
import plotly.graph_objects as go

# Prepara de datos
cols_str = ['InternetService', 'Contract', 'PaymentMethod']
media_churn = datos['Churn'].mean()
grafico = []
for col in cols_str:
    churn_cat = datos.groupby(col)['Churn'].mean().sort_values(ascending=False)
    orden = churn_cat.index
    valores = churn_cat.values
    colores = ['crimson' if val > media_churn else 'lightgray' for val in valores]
    grafico.append({
        "x": orden,
        "y": valores,
        "color": colores,
        "col": col
    })

# Genera gráfico
fig = go.Figure()

# Crea las barras de cada gráfico
for i, barra in enumerate(grafico):
    visible = True if i == 0 else False
    fig.add_trace(go.Bar(
        x=barra["x"],
        y=barra["y"],
        marker_color=barra["color"],
        name=barra["col"],
        visible=visible
    ))

# Media de churn - baja
fig.add_shape(
    type="line",
    x0=-0.5,
    x1=len(grafico[0]['x']),
    y0=media_churn,
    y1=media_churn,
    line=dict(color="gray", dash="dash"),
    name="Media churn"
)

# Crea menú desplegable
menu_desp = []
for i, barra in enumerate(grafico):
    visibility = [False] * len(grafico)
    visibility[i] = True
    menu_desp.append(dict(label=barra["col"], method="update", args=[{"visible": visibility}, {"title": f"Tasa de baja según {barra['col']}"}]))

# Edita y muestra el gráfico
fig.update_layout(
    updatemenus=[dict(active=0, buttons=menu_desp, x=1.1)],
    yaxis=dict(title="Proporción de baja", range=[0, 1]),
    xaxis=dict(title="Categoría"),
    height=400
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Gráfico de distribución de evasión de clientes por variables binarias

# %%
# Prepara de datos
cols_bin_filtradas = [col for col in cols_bin if col != 'Churn']
media_churn = datos['Churn'].mean()
barras_bin = []
for col in cols_bin_filtradas:
    churn_cat = datos.groupby(col)['Churn'].mean()
    categorias = ['No' if i == 0 else 'Sí' for i in churn_cat.index]
    valores = churn_cat.values
    colores = ['crimson' if val > media_churn else 'lightgray' for val in valores]
    barras_bin.append({
        "x": categorias,
        "y": valores,
        "color": colores,
        "col": col
    })

# Genera gráfico
fig = go.Figure()

# Crea las barras de cada gráfico
for i, barra in enumerate(barras_bin):
    visible = True if i == 0 else False
    fig.add_trace(go.Bar(
        x=barra["x"],
        y=barra["y"],
        marker_color=barra["color"],
        name=barra["col"],
        visible=visible
    ))

# Media de churn - baja
fig.add_shape(
    type="line",
    x0=-0.5,
    x1=1.5,
    y0=media_churn,
    y1=media_churn,
    line=dict(color="gray", dash="dash"),
)

# Crea menú desplegable
menu_desp = []
for i, barra in enumerate(barras_bin):
    visibility = [False] * len(barras_bin)
    visibility[i] = True
    menu_desp.append(dict(label=barra["col"],
                                 method="update",
                                 args=[{"visible": visibility},
                                       {"title": f"Tasa de churn según {barra['col']}"}]))

# Edita y muestra el gráfico
fig.update_layout(
    updatemenus=[dict(active=0, buttons=menu_desp, x=1.1)],
    yaxis=dict(title="Proporción de baja", range=[0, 1]),
    xaxis=dict(title=None),
    showlegend=False,
    height=400
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Gráfico de distribución de evasión de clientes por variables numéricas

# %%
# Prepara datos
cols_num = ['tenure', 'Monthly', 'Total', 'Cuentas_Diarias']

# Genera gráfico
fig = go.Figure()

# Genera 10 barras por cada variable numérica
for i, col in enumerate(cols_num):
    datos[f'{col}_decil'] = pd.qcut(datos[col], q=10)
    churn_por_decil = datos.groupby(f'{col}_decil', observed=False)['Churn'].mean()
    x_labels = churn_por_decil.index.astype(str)
    colores = ['crimson' if val > media_churn else 'lightgray' for val in churn_por_decil]
    fig.add_trace(go.Bar(
        x=x_labels,
        y=churn_por_decil.values,
        name=col,
        marker_color=colores,
        visible=(i == 0)
    ))

# Media de churn - baja
fig.add_shape(
    type="line",
    x0=-0.5,
    x1=10,
    y0=media_churn,
    y1=media_churn,
    line=dict(color="gray", dash="dash"),
)

# Crea menú desplegable
menu_desp = []
for i, col in enumerate(cols_num):
    visibility = [False] * len(cols_num)
    visibility[i] = True
    menu_desp.append(dict(
        label=col,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Tasa de baja según rangos de {col}",
               "xaxis.title": f"Rangos de {col}",
               "yaxis.title": "Tasa de baja"}]
    ))

# Edita y muestra el gráficof
fig.update_layout(
    xaxis_title=f"Rangos de {cols_num[0]}",
    yaxis_title="Tasa de baja",
    updatemenus=[dict(buttons=menu_desp, active=0, x=1.05)],
    height=450
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ### **Introducción**

# %% [markdown]
# El presente informe detalla los pasos del análisis de evasión de clientes (churn / baja) en la empresa TelecomX LATAM. Dicho informe busca identificar las posibles causas del alto índice de evasión de cliientes, así como proponer recomendaciones para mantener la fidelización de los mismos.

# %% [markdown]
# ### **Limpieza y Tratamiento de Datos**

# %% [markdown]
# A partir de un conjunto de datos en formato JSON, con información detallada de más de 7.000 clientes, se realizaron los siguientes pasos de limpieza y transformación:
# *   Flatten de columnas anidades en un solo DataFrame plano.
# *   Conversión de variables con categorías "Yes"/"No" en binarias.
# *   Limpieza de registros vacíos e inconsistentes: debido a la escasa cantidad de estos valores - máx 235/7267, se optó por eliminar estos registros del análisis.
# *   Estandarización de variables categóricas a str lowercase y de variables numéricas a tipo float o int según correspondiese.
# *   Creación de variable "Cuentas_Diarias": que refleja el costo diario promedio de servicios.

# %% [markdown]
# ### **Análisis Exploratorio de Datos**

# %% [markdown]
# Se efectuaron análisis descriptivos junto con sus visualización en gráficos dinámicos, a fin de identificar más fácilmente los patrones que puedan estar asociados a la evasión de clientes.

# %% [markdown]
# #### Estadísticas Generales

# %% [markdown]
# *   La tasa general de churn es de 26.58%
# *   Porcentaje de baja sobre el total de clientes:
#       - por servicio de internet contratado: ninguno 7,43% - dsl 18,99% - fibra óptica 41,89% -
#       - por tipo de contrato: a 2 años 2,84% - a 1 año 11,27% - por mes 42,70%
#       - por forma de pago: credit card automatic 15,25% - debito bancario automatico 16,73% - factura por mail 19,20% - factura electrónica 45,28%
# *   Porcentaje de baja sobre el total de clientes:
#       - edad menor a 65 años 23,65% - edad mayor o igual a 65 años 41,68%
#       - sin servicio de teléfono 25% - con servicio de teléfono 26,74%
#       - sin múltiples líneas 25,06% - con múltiples líneas 28,64%
#       - sin servicio de seguridad online 31,37% - con servicio de seguridad online 14,64%
#       - sin servicio de backup online 29,21% - con servicio de backup online %21,56
#       - sin servicio de protección de dispositivo 28,69% - con servicio de protección de dispositivo 22,53%
#       - sin servicio de soporte técnico 31,22% - con servicio de soporte técnico 15,19%
#       - sin servicio de streamingTV 24,37% - con servicio de streamingTV 30,11%
#       - sin servicio de streamingMovies 24,43% - con servicio de streamingMovies 29,95%
#       - con factura en papel 16,37% - con factura electrónica 33,58%
# *   Porcentaje de baja sobre el total de clientes:
#       - por rango mensual de tenencia del cliente: 0 a 2 meses 59,10% - 2 a 6 meses 45,39% - 6 a 12 meses 35,88% - 12 a 20 meses 30,92% - 20 a 29 meses 22,86% - 29 a 40 meses 21,89% - 40 a 50 meses 17,63% - 50 a 60 meses 13,61% - 60 a 69 meses 9,25% - 69 a 72 meses 3,53%
#       - por importe pago diario: 0,60 a 0,67 9,32% - 0,67 a 0,84 9,95% - 0,84 a 1,53 26,97% -  1,53 a 1,96 23,80% - 1,96 a 2,34 21,76% - 2,34 a 2,64 38,17% - 2,64 a 2,85 38,20% - 2,85 a 3,14 33,71% - 3,14 a 3,42 41,15% - 3,42 a 3,96 24,82%.
#       - por importe pago mensual: 18,24 a 20,5 8,54% - 20,5 a 25,05 9,82% - 25,05 a 45,9 25,35% - 45,9 a 58,92 24,60% - 58,92 a 70,35 21,67% - 70,35 a 79,15 38,22% - 79,15 a 85,53 37,89% - 85,53 a 94,3 34,08% - 94,3 a 102,64 41,23% - 102,64 a 118,75 24,71%
#       - por importe pago total: 18,79 a 84,6 52,34% - 84,6 a 267,07 39,60% - 267,07 a 551,99 30,58% - 551,99 a 944,17 27,31% - 944,17 a 1397,47 22,04% - 1397,47 a 2048,95 19,48% - 2048,95 a 3141,13 28,16% - 3141,13 a 4475,41 17,92% - 4475,41 a 5976,64 15,78% - 5976,64 a 8684,8 12,5%

# %% [markdown]
# ### **Conclusiones e Insights**

# %% [markdown]
# *   Factores demográficos
#       - Los usuarios mayores de 65 años constituyen un segmento especialmente vulnerable a la baja.
# *   Factores de servicio
#       - Los clientes con fibra cancelan en proporción mucho mayor que los de DSL o aquellos sin internet.
#       - Los contratos mensuales son el grupo de mayor riesgo: casi la mitad de ellos se va.
#       - Los clientes que usan facturación electrónica tienen casi un 50 % de probabilidad de irse, muy por encima de quienes pagan por otros medios.
#       - La contratación de servicio telefónico no parece tener gran incidencia en la baja de clientes.
#       - Lo mismo sucede con la contratación de múltiples líneas.
#       - Los clientes que contratan seguridad en línea mantienen con mayor tasa su fidelización.
#       - El servicio adicional de backup y de protección de dispositivo no presentan gran incidencia en la tasa de bajas. Lo mismo sucede con la contratación de streaming (tanto TV como Movies).
#       - El servicio de soporte técnico tiene alto impacto: más de la mitad de clientes con soporte se quedan.
# *   Factores de facturación
#       - El churn desciende conforme aumenta el tiempo. La fase crítica es el primer año, especialmente los primeros 2 meses.
#       - Es notable el salto a 38–41 % de churn cuando el gasto se ubica entre 2,34 y 3,42 USD diarios.
#       - Del mismo modo, los clientes con facturación mensual entre 70 y 85 USD tienen tasas de churn muy altas (38 %–41 %).
#       - El mayor churn (52 %) ocurre en clientes con gasto histórico total más bajo (18–84 USD), probablemente debido a que sean usuarios nuevos o de contratación de paquetes básicos.

# %% [markdown]
# ### **Recomendaciones**

# %% [markdown]
# *   Estrategias dirigidas a usuarios senior: como programas de asistencia telefónicas o planes simplificados para sus requerimientos específicos.
# * Campañas de marketing y promoción de servicios de valor añadido: como OnlineSecurity y TechSupport que reducen el churn a la mitad.
# *   Fidelización temprana: incluyendo...
#       - Ofertas promocionales para extender el plazo de contrato a 1 o 2 años.
#       - Seguimiento personalizado durante los primeros dos meses para corroborar la satisfacción con el servicio.
# *   Profundización de análisis mediante encuestas a clientes sobre ciertos aspectos:
#       - Si la facturación electrónica implica una dificultad para los clientes, ya que hay una alta tase de churn en dicho tipo de facturación, en comparación con la facturación en papel.
#       - Si el servicio de fibra óptica es de calidad, ya que posee un churn de casi el 42%, siendo el servicio con mayor riesgo de cancelación. Contraponer a el tipo de servicio de fibra óptica y los precios que ofrece la competencia.
#       - Si los clientes con mayores gastos diarios y mensuales (donde se produce la mayor tasa de churn), poseen la percepción de que el costo es "demasiado caro" para el servicio adquirido. Con qué se podría dar valor extra.
